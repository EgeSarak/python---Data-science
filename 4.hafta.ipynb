# %%
import pandas as pd
import hashlib
df=pd.read_csv("data2.csv")
from utility import *
import json

# %%
a=hashlib.md5()

CORPUS={}
for line in readTextFile2("some.txt"):
    ilkharf=line[0]
    if ilkharf not in CORPUS:
        CORPUS[ilkharf]=[]
        CORPUS[ilkharf].append(line)
    
print(json.dumps(CORPUS))    
    
    #CORPUS[line]=(line)
    #a.update(line.encode("utf-8"))
    #print(line,"===>",a.digest())
# Out:
# {"p": ["pay\u0131z"], "s": ["sarf\u0131"], "\u00e7": ["\u00e7ektirmemeleri"], "a": ["an\u0131msananlar\u0131"], "b": ["bat\u0131lsa"], "y": ["y\u00f6neltmiyorsun"], "k": ["kadifeydi"], "i": ["iddia"], "t": ["trigonometrisini"], "\u00f6": ["\u00f6ng\u00f6r\u00fcyorlarsa"], "f": ["f\u0131kras\u0131nda"], "m": ["m\u00fc\u015ftekile\u015fe"], "u": ["ula\u015famay\u0131p"], "e": ["e\u011flenmiyorlar"], "v": ["verimsizlikleri"], "d": ["diziverir"], "c": ["canl\u0131s\u0131nda"], "g": ["ge\u00e7inmedi\u011fimiz"], "h": ["havac\u0131l\u0131\u011f\u0131m\u0131zda"], "l": ["lece"], "o": ["oynayabilece\u011fimize"], "n": ["nikahs\u0131zlar"], "\u015f": ["\u015fifan\u0131z\u0131"], "r": ["riyallerini"], "\u00fc": ["\u00fcstlenmeyeceklerine"], "\u0131": ["\u0131slanm\u0131yordu"], "z": ["zaferindense"], "j": ["jantlar\u0131m\u0131za"]}

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns
sns.set_theme()
corr=df.corr()
axx=sns.heatmap(corr)

# %%
import pickle
model_verisi={"lion":"yellow","kitty":"red"}
pickle.dump(model_verisi,open("benim_modelim.pickle","wb"))

# %%
from flask import Flask,jsonify
from flask import request
app=Flask(__name__)

@app.route("/")
def hello_world():
    return "<p>Hello,World!</p>"

app.run(port=5000)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
